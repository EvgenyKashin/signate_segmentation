# %%
from pathlib import Path
import imageio
import matplotlib.pyplot as plt
# %matplotlib inline

base = Path('/mnt/ssd/kashin/ai_edge/segmentation/')
train = base / 'seg_test_images'
submit = base / 'runs/full_labels/submit_full_eval'

# %% [markdown]
# ## Visualization submit

# %%
ls /mnt/ssd/kashin/ai_edge/segmentation/runs/full_labels
# Out:
# model_0_10_ep.pth  model_0_40_ep.pth  model_0_best.pth     submit_full_eval/
# model_0_20_ep.pth  model_0_50_ep.pth  params.json          train_0.log
# model_0_30_ep.pth  model_0_best_.pth  params_predict.json  val_full_full/

# %%
imageio.imread(p).shape
# Out:
# (1216, 1936, 3)

# %%
for p in list(submit.iterdir())[:5]:
    plt.figure()
    tr = train / p.name.replace('png', 'jpg')
    img = imageio.imread(p) * 0.6 + imageio.imread(tr) * 0.4
    plt.imshow(img.astype(int))
